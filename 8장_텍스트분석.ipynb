# %%
import nltk
from nltk.tokenize import sent_tokenize

nltk.data.path.append('C:/Users/default.DESKTOP-IB7ET6G/AppData/Roaming/nltk_data')
nltk.download('punkt_tab')
text_sample = 'The Matrix is everywhere its all around us, here even in this room. You can see it out your window or on your television. You feel it when you go to work, or go to church or pay your taxes.'

sentences = sent_tokenize(text_sample)

print(type(sentences), len(sentences))
print(sentences)
# Out:
# <class 'list'> 3
# ['The Matrix is everywhere its all around us, here even in this room.', 'You can see it out your window or on your television.', 'You feel it when you go to work, or go to church or pay your taxes.']
# [nltk_data] Downloading package punkt_tab to C:\Users\default.DESKTOP-
# [nltk_data]     IB7ET6G\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# 문장 토큰화  
from nltk import word_tokenize

sentence = "The Matrix is everywhere its all around us, here even in this room."
words = word_tokenize(sentence)
print(type(words),len(words))
print(words)
# Out:
# <class 'list'> 15
# ['The', 'Matrix', 'is', 'everywhere', 'its', 'all', 'around', 'us', ',', 'here', 'even', 'in', 'this', 'room', '.']

# %%
#문장 토큰화 + 단어 토큰화 
from nltk import word_tokenize , sent_tokenize

def tokenize_test(text):
    #문장 별로 분리 토큰
    sentences = sent_tokenize(text)
    word_tokens = [word_tokenize(sentence) for sentence in sentences]
    return word_tokens

word_tokens = tokenize_test(text_sample)
print(word_tokens)
# Out:
# [['The', 'Matrix', 'is', 'everywhere', 'its', 'all', 'around', 'us', ',', 'here', 'even', 'in', 'this', 'room', '.'], ['You', 'can', 'see', 'it', 'out', 'your', 'window', 'or', 'on', 'your', 'television', '.'], ['You', 'feel', 'it', 'when', 'you', 'go', 'to', 'work', ',', 'or', 'go', 'to', 'church', 'or', 'pay', 'your', 'taxes', '.']]

# %%
# COO 희소행렬
from scipy import sparse
import numpy as np
# 0이 아닌 데이터 추출
data = np.array([3,1,2])

#행 열 위치 배열로 생성
row_pos = np.array([0,0,1])
col_pos = np.array([0,2,1])

#sparse 패키지의 coo_matrix 이용해 coo형식의 희소행렬 생성하기
sparse_coo = sparse.coo_matrix((data,(row_pos,col_pos))) # 희소 행렬 객체 변수라서 toarray()로 밀집형태 바꾸기 

#다시 원래 형태가 됨 
sparse_coo.toarray()
# Out:
# array([[3, 0, 1],
#        [0, 2, 0]])

# %%
# CSR 희소행렬 
from scipy import sparse
dense2 = np.array([[0,0,1,0,0,5],
                  [1,4,0,3,2,5],
                  [0,6,0,3,0,0],
                  [2,0,0,0,0,0],
                  [0,0,0,7,0,8],
                  [1,0,0,0,0,0]])

# 0이 아닌 데이터 추출
data2= np.array([1,5,1,4,3,2,5,6,3,2,7,8,1])

#위치 array로
row_pos = np.array([0,0,1,1,1,1,1,2,2,3,4,4,5])
col_pos = np.array([2,5,0,1,3,4,5,1,3,0,3,5,0])

#COO 형식으로 변환
sparse_coo = sparse.coo_matrix((data2,(row_pos,col_pos)))

#행 위치 배열의 시작 인덱스배열로
row_pose_idx =np.array([0,2,7,9,10,12,13])

#CSR 형식으로 변환
sparse_csr = sparse.csr_matrix((data2,col_pos,row_pose_idx))

# %%
#### ➡️➡️➡️➡️➡️➡️➡️➡️➡️ 텍스트 정규화 실습 ➡️➡️➡️➡️➡️➡️➡️➡️➡️ ###### 
from sklearn.datasets import fetch_20newsgroups
news_data = fetch_20newsgroups(subset='all',random_state=156)
print(news_data.keys())
# Out:
# dict_keys(['data', 'filenames', 'target_names', 'target', 'DESCR'])

# %%
# subset='train’ 으로 학습용 데이터만 추출, remove=('headers', 'footers' , 'quotes' ）로 내용만 추출
train_news = fetch_20newsgroups(subset='train',remove=('headers','footers','quotes'),random_state=156)
X_train = train_news.data
y_train  =train_news.target

test_news= fetch_20newsgroups(subset='test',remove=('headers','footers','quotes'),random_state=156)
X_test= test_news.data
y_test =test_news.target

print('학습 데이터 크기 {0}, 테스트 데이터 크기 {1}'.format (len(train_news.data), len(test_news.data)))
# Out:
# 학습 데이터 크기 11314, 테스트 데이터 크기 7532

# %%
from sklearn.feature_extraction.text import CountVectorizer

#✏️텍스트 -> 숫자 행렬 과정 
# 1.countvectorizer로 피처 벡터화 수행
cnt_vect = CountVectorizer()
cnt_vect.fit(X_train)

X_train_cnt_vect = cnt_vect.transform(X_train)
X_test_cnt_vect = cnt_vect.transform(X_test)

print(X_train_cnt_vect.shape) #(11314, 101631) 문서 11314 , 단어 101631
# Out:
# (11314, 101631)

# %%
# 빅처 벡터화된 데이터에 로지스틱 회귀 적용해 뉴스그룹 분류
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')

lr_clf = LogisticRegression(solver='liblinear')
lr_clf.fit(X_train_cnt_vect,y_train)
pred = lr_clf.predict(X_test_cnt_vect)
print(accuracy_score(y_test,pred)) #
# Out:
# 0.6165693043016464

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# TF_IDF 벡터화 적용
tfidf_vect = TfidfVectorizer(stop_words='english',ngram_range=(1,2),max_df=300)
tfidf_vect.fit(X_train)

X_train_tfidf_vect = tfidf_vect.transform(X_train)
X_test_tfidf_vect = tfidf_vect.transform(X_test)

print(X_train_tfidf_vect.shape) #(11314, 101631) 문서 11314 , 단어 101631  

lr_clf = LogisticRegression(solver='liblinear')
lr_clf.fit(X_train_tfidf_vect,y_train)
pred = lr_clf.predict(X_test_tfidf_vect)
print(accuracy_score(y_test,pred))
# Out:
# (11314, 943453)
# 0.6901221455124801

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# 로지스틱 회귀 모델
lr_clf = LogisticRegression(solver='liblinear')
# 하이퍼파라미터 후보
params = {'C': [0.01, 0.1, 1, 5, 10]}
# GridSearchCV 설정
grid_cv_lr = GridSearchCV(
    lr_clf,
    param_grid=params,
    cv=3,
    scoring='accuracy',
    verbose=1
)
# 학습
grid_cv_lr.fit(X_train_tfidf_vect, y_train)
# 최적 파라미터 출력
print("Logistic Regression best C parameter:", grid_cv_lr.best_params_)
# 예측
pred = grid_cv_lr.predict(X_test_tfidf_vect)
# 정확도 평가
print("TF-IDF Logistic Regression accuracy: {:.3f}".format(accuracy_score(y_test, pred)))
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# Logistic Regression best C parameter: {'C': 10}
# TF-IDF Logistic Regression accuracy: 0.704

# %%
import pandas as pd

review_df = pd.read_csv('./labeledTrainData.tsv',header=0,sep="\t",quoting=3)
review_df.head(3)
# Out:
#          id  sentiment                                             review
# 0  "5814_8"          1  "With all this stuff going down at the moment ...
# 1  "2381_9"          1  "\"The Classic War of the Worlds\" by Timothy ...
# 2  "7759_3"          0  "The film starts with a manager (Nicholas Bell...

# %%
import re

review_df['review'] = review_df['review'].str.replace('<br/>',' ')
review_df['review'] = review_df['review'].apply(lambda x : re.sub("[^a-zA-Z]"," ",x))

from sklearn.model_selection import train_test_split

class_df = review_df['sentiment']
feature_df = review_df.drop(['id','sentiment'],axis=1,inplace = False)
X_train , X_test , y_train , y_test = train_test_split(feature_df,class_df,test_size=0.3,random_state=150)
X_train.shape,X_test.shape
# Out:
# ((17500, 1), (7500, 1))

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split

# Pipeline 생성
pipeline = Pipeline([
    ('cnt_vect', CountVectorizer(stop_words='english', ngram_range=(1,2))),
    ('lr_clf', LogisticRegression(solver='liblinear', C=10))
])

pipeline.fit(X_train['review'], y_train)
pred = pipeline.predict(X_test['review'])
pred_probs = pipeline.predict_proba(X_test['review'])[:,1] # 긍정확


print("Accuracy:", accuracy_score(y_test, pred))
print("ROC-AUC:", roc_auc_score(y_test, pred_probs))
# Out:
# Accuracy: 0.886
# ROC-AUC: 0.9515079527847761

# %%
pipeline = Pipeline([
    ('tfidf_vect', TfidfVectorizer(stop_words='english', ngram_range=(1,2))),
    ('lr_clf', LogisticRegression(solver='liblinear', C=10))
])

pipeline.fit(X_train['review'], y_train)
pred = pipeline.predict(X_test['review'])
pred_probs = pipeline.predict_proba(X_test['review'])[:,1] # 긍정확

print("Accuracy:", accuracy_score(y_test, pred))
print("ROC-AUC:", roc_auc_score(y_test, pred_probs))
# Out:
# Accuracy: 0.8954666666666666
# ROC-AUC: 0.9607002267916842

# %%
# 비지도 학습 기반 감성 분석

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to C:\Users\default.DESKTOP-
# [nltk_data]    |     IB7ET6G\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\default.DESKTOP-
# [nltk_data]    |     IB7ET6G\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\default.DESKTOP-
# [nltk_data]    |     IB7ET6G\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\default.DESKTOP-
# [nltk_data]    |     IB7ET6G\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_eng.zip.
# ...

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer 
senti_analyzer = SentimentIntensityAnalyzer( ) 
senti_scores = senti_analyzer.polarity_scores(review_df['review'][0]) 
print (senti_scores)
# Out:
# {'neg': 0.13, 'neu': 0.744, 'pos': 0.126, 'compound': -0.8278}

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# 1. 텍스트 데이터 정의 (Matrix 리스트)
doc_list = [
    'if you take the blue pill, the story ends',
    'if you take the red pill, you stay in Wonderland',
    'if you take the red pill, I show you how deep the rabbit hole goes'
]

# 2. TfidfVectorizer 객체 생성
tfidf_vect_simple = TfidfVectorizer()

# 3. 학습 및 변환 (fit_transform)
feature_vect_simple = tfidf_vect_simple.fit_transform(doc_list)

# 4. 결과 출력
print(feature_vect_simple.todense()[0])
# Out:
# [[0.4155636  0.         0.4155636  0.         0.         0.
#   0.24543856 0.         0.24543856 0.         0.         0.
#   0.         0.4155636  0.24543856 0.49087711 0.         0.24543856]]
